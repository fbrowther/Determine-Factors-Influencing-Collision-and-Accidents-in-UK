# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sqlalchemy import create_engine

# %%
data_acc = pd.read_csv("./Resources/accident_data.csv")
print("\n Quick view of the head of the data: \n")
data_acc.head()
# Out:
#  Quick view of the head of the data:
#   Accident_Index 1st_Road_Class  1st_Road_Number 2nd_Road_Class  \
# 0  200501BS00001              A           3218.0            NaN
# 1  200501BS00002              B            450.0              C
# 2  200501BS00003              C              0.0            NaN
# 3  200501BS00004              A           3220.0            NaN
# 4  200501BS00005            NaN              0.0            NaN
#
#    2nd_Road_Number Accident_Severity Carriageway_Hazards        Date  \
# 0              0.0           Serious                None  04/01/2005
# 1              0.0            Slight                None  05/01/2005
# 2              0.0            Slight                None  06/01/2005
# 3              0.0            Slight                None  07/01/2005
# 4              0.0            Slight                None  10/01/2005
#
#   Day_of_Week  Did_Police_Officer_Attend_Scene_of_Accident  ...  \
# ...

# %%
data_acc["Date"].unique
# Out:
# <bound method Series.unique of 0          04/01/2005
# 1          05/01/2005
# 2          06/01/2005
# 3          07/01/2005
# 4          10/01/2005
#               ...
# 1048570    18/02/2010
# 1048571    21/02/2010
# 1048572    23/02/2010
# 1048573    23/02/2010
# 1048574    28/02/2010
# Name: Date, Length: 1048575, dtype: object>

# %%
Speed_data = data_acc["Speed_limit"].value_counts()
Speed_data
# Out:
# 30    667700
# 60    177052
# 40     86150
# 70     79435
# 50     30902
# 20      7306
# 10        15
# 15        15
# Name: Speed_limit, dtype: int64

# %%
Road_conditions = data_acc["Road_Surface_Conditions"].value_counts()
Road_conditions
# Out:
# Dry                     712370
# Wet or damp             302250
# Frost or ice             23857
# Snow                      7451
# Flood over 3cm. deep      1458
# Name: Road_Surface_Conditions, dtype: int64

# %%
Weather_conditions = data_acc["Weather_Conditions"].value_counts()
Weather_conditions
# Out:
# Fine no high winds       831083
# Raining no high winds    125484
# Other                     26486
# Raining + high winds      14697
# Fine + high winds         13554
# Snowing no high winds      8542
# Fog or mist                6051
# Snowing + high winds       1286
# Name: Weather_Conditions, dtype: int64

# %%
data_veh = pd.read_csv("./Resources/vehicle_data.csv",encoding='latin')
print("\n Quick view of the head of the data: \n")
data_veh.head()
# Out:
#  Quick view of the head of the data:
#   Accident_Index Age_Band_of_Driver  Age_of_Vehicle  \
# 0  200401BS00001            26 - 35             3.0
# 1  200401BS00002            26 - 35             NaN
# 2  200401BS00003            26 - 35             4.0
# 3  200401BS00003            66 - 75             NaN
# 4  200401BS00004            26 - 35             1.0
#
#           Driver_Home_Area_Type  Driver_IMD_Decile  Engine_Capacity_.CC.  \
# 0                    Urban area                4.0                1588.0
# 1                    Urban area                3.0                   NaN
# 2  Data missing or out of range                NaN                 998.0
# 3  Data missing or out of range                NaN                   NaN
# 4                    Urban area                4.0                 124.0
#
#   Hit_Object_in_Carriageway Hit_Object_off_Carriageway  \
# 0                      None                       None
# 1                      None                       None
# ...

# %%
Vehicle_manu = data_veh["Vehicle_Manoeuvre"].value_counts()
Vehicle_manu
# Out:
# Going ahead other                      994636
# Turning right                          216201
# Slowing or stopping                    177548
# Waiting to go - held up                155643
# Going ahead right-hand bend             90893
# Parked                                  88354
# Moving off                              87295
# Going ahead left-hand bend              78667
# Turning left                            70143
# Overtaking moving vehicle - offside     43773
# Waiting to turn right                   36738
# Reversing                               30435
# Overtaking static vehicle - offside     26472
# Changing lane to left                   19164
# Changing lane to right                  18900
# U-turn                                  17209
# Waiting to turn left                    12497
# Overtaking - nearside                   11269
# Data missing or out of range             1368
# Name: Vehicle_Manoeuvre, dtype: int64

# %%
data_acc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 34 columns):
#  #   Column                                       Non-Null Count    Dtype
# ---  ------                                       --------------    -----
#  0   Accident_Index                               1048575 non-null  object
#  1   1st_Road_Class                               742986 non-null   object
#  2   1st_Road_Number                              1048573 non-null  float64
#  3   2nd_Road_Class                               608751 non-null   object
#  4   2nd_Road_Number                              1037772 non-null  float64
#  5   Accident_Severity                            1048575 non-null  object
#  6   Carriageway_Hazards                          1048546 non-null  object
#  7   Date                                         1048575 non-null  object
#  8   Day_of_Week                                  1048575 non-null  object
# ...

# %%
data_veh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2177205 entries, 0 to 2177204
# Data columns (total 24 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   Accident_Index                    object
#  1   Age_Band_of_Driver                object
#  2   Age_of_Vehicle                    float64
#  3   Driver_Home_Area_Type             object
#  4   Driver_IMD_Decile                 float64
#  5   Engine_Capacity_.CC.              float64
#  6   Hit_Object_in_Carriageway         object
#  7   Hit_Object_off_Carriageway        object
#  8   Journey_Purpose_of_Driver         object
#  9   Junction_Location                 object
#  10  make                              object
#  11  model                             object
#  12  Propulsion_Code                   object
#  13  Sex_of_Driver                     object
#  14  Skidding_and_Overturning          object
#  15  Towing_and_Articulation           object
# ...

# %% [markdown]
# #  Create new data with select columns

# %%
new_data_acc = data_acc[['Accident_Index', 'Accident_Severity', 'Day_of_Week', 'Speed_limit', 'Road_Surface_Conditions', 'Weather_Conditions']].copy()
new_data_acc.head()
# Out:
#   Accident_Index Accident_Severity Day_of_Week  Speed_limit  \
# 0  200501BS00001           Serious     Tuesday           30
# 1  200501BS00002            Slight   Wednesday           30
# 2  200501BS00003            Slight    Thursday           30
# 3  200501BS00004            Slight      Friday           30
# 4  200501BS00005            Slight      Monday           30
#
#   Road_Surface_Conditions     Weather_Conditions
# 0             Wet or damp  Raining no high winds
# 1                     Dry     Fine no high winds
# 2                     Dry     Fine no high winds
# 3                     Dry     Fine no high winds
# 4             Wet or damp     Fine no high winds

# %%
new_data_veh = data_veh[['Accident_Index', 'Age_Band_of_Driver','Age_of_Vehicle','make','model','Sex_of_Driver', 'Vehicle_Manoeuvre']].copy() 
new_data_veh.head()
# Out:
#   Accident_Index Age_Band_of_Driver  Age_of_Vehicle              make  \
# 0  200401BS00001            26 - 35             3.0             ROVER
# 1  200401BS00002            26 - 35             NaN               BMW
# 2  200401BS00003            26 - 35             4.0            NISSAN
# 3  200401BS00003            66 - 75             NaN  LONDON TAXIS INT
# 4  200401BS00004            26 - 35             1.0           PIAGGIO
#
#                    model Sex_of_Driver  Vehicle_Manoeuvre
# 0         45 CLASSIC 16V          Male  Going ahead other
# 1                     C1          Male  Going ahead other
# 2  MICRA CELEBRATION 16V          Male      Turning right
# 3         TXII GOLD AUTO          Male  Going ahead other
# 4              VESPA ET4          Male  Going ahead other

# %% [markdown]
# # Change the column names and drop NaN, data missing/ out of range values.

# %%
accident = new_data_acc.rename(
    columns = {"Accident_Index": "id",
                "Accident_Severity": "severity",
                "Speed_limit": "SpeedLimit",
                "Road_Surface_Conditions": "RoadConditions",
                "Day_of_Week": "day",
                "Weather_Conditions": "weather",
                
    }
)

# %%
accident
# Out:
#                     id severity        day  SpeedLimit RoadConditions  \
# 0        200501BS00001  Serious    Tuesday          30    Wet or damp
# 1        200501BS00002   Slight  Wednesday          30            Dry
# 2        200501BS00003   Slight   Thursday          30            Dry
# 3        200501BS00004   Slight     Friday          30            Dry
# 4        200501BS00005   Slight     Monday          30    Wet or damp
# ...                ...      ...        ...         ...            ...
# 1048570  201091NM01760   Slight   Thursday          60            Dry
# 1048571  201091NM01881   Slight     Sunday          60   Frost or ice
# 1048572  201091NM01935   Slight    Tuesday          30   Frost or ice
# 1048573  201091NM01964  Serious    Tuesday          60    Wet or damp
# 1048574  201091NM02142  Serious     Sunday          60    Wet or damp
#
#                        weather
# 0        Raining no high winds
# 1           Fine no high winds
# ...

# %%
accident.severity.unique()
# Out:
# array(['Serious', 'Slight', 'Fatal'], dtype=object)

# %%
accident.day.unique()
# Out:
# array(['Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Monday', 'Saturday',
#        'Sunday'], dtype=object)

# %%
accident.weather.unique()
# Out:
# array(['Raining no high winds', 'Fine no high winds', nan,
#        'Snowing no high winds', 'Other', 'Fine + high winds',
#        'Raining + high winds', 'Fog or mist', 'Snowing + high winds'],
#       dtype=object)

# %%
accident.SpeedLimit.unique()
# Out:
# array([30, 40, 50, 20, 60, 70, 10, 15])

# %%
accident.RoadConditions.unique()
# Out:
# array(['Wet or damp', 'Dry', 'Frost or ice', 'Snow',
#        'Flood over 3cm. deep', nan], dtype=object)

# %%
accident.id.unique()
# Out:
# array(['200501BS00001', '200501BS00002', '200501BS00003', ...,
#        '201091NM01935', '201091NM01964', '201091NM02142'], dtype=object)

# %%
accident_data = accident.dropna()
accident_data
# Out:
#                     id severity        day  SpeedLimit RoadConditions  \
# 0        200501BS00001  Serious    Tuesday          30    Wet or damp
# 1        200501BS00002   Slight  Wednesday          30            Dry
# 2        200501BS00003   Slight   Thursday          30            Dry
# 3        200501BS00004   Slight     Friday          30            Dry
# 4        200501BS00005   Slight     Monday          30    Wet or damp
# ...                ...      ...        ...         ...            ...
# 1048570  201091NM01760   Slight   Thursday          60            Dry
# 1048571  201091NM01881   Slight     Sunday          60   Frost or ice
# 1048572  201091NM01935   Slight    Tuesday          30   Frost or ice
# 1048573  201091NM01964  Serious    Tuesday          60    Wet or damp
# 1048574  201091NM02142  Serious     Sunday          60    Wet or damp
#
#                        weather
# 0        Raining no high winds
# 1           Fine no high winds
# ...

# %% [markdown]
# ## Final accident_data file

# %%
accident_data.set_index("id")
# Out:
#               severity        day  SpeedLimit RoadConditions  \
# id
# 200501BS00001  Serious    Tuesday          30    Wet or damp
# 200501BS00002   Slight  Wednesday          30            Dry
# 200501BS00003   Slight   Thursday          30            Dry
# 200501BS00004   Slight     Friday          30            Dry
# 200501BS00005   Slight     Monday          30    Wet or damp
# ...                ...        ...         ...            ...
# 201091NM01760   Slight   Thursday          60            Dry
# 201091NM01881   Slight     Sunday          60   Frost or ice
# 201091NM01935   Slight    Tuesday          30   Frost or ice
# 201091NM01964  Serious    Tuesday          60    Wet or damp
# 201091NM02142  Serious     Sunday          60    Wet or damp
#
#                              weather
# id
# 200501BS00001  Raining no high winds
# 200501BS00002     Fine no high winds
# 200501BS00003     Fine no high winds
# 200501BS00004     Fine no high winds
# ...

# %%
vehicle0 = new_data_veh.rename(
    columns = {"Accident_Index": "id",
                "Age_Band_of_Driver": "driverAge",
                "Age_of_Vehicle": "vehicleAge",
                "make": "make",
                "model": "model",
                "Sex_of_Driver": "sex",
                "Vehicle_Manoeuvre": "VehicleManoeuvre"
    }
)

# %%
vehicle0
# Out:
#                     id driverAge  vehicleAge              make  \
# 0        200401BS00001   26 - 35         3.0             ROVER
# 1        200401BS00002   26 - 35         NaN               BMW
# 2        200401BS00003   26 - 35         4.0            NISSAN
# 3        200401BS00003   66 - 75         NaN  LONDON TAXIS INT
# 4        200401BS00004   26 - 35         1.0           PIAGGIO
# ...                ...       ...         ...               ...
# 2177200  2016984131116   21 - 25        14.0              MINI
# 2177201  2016984131116   56 - 65         NaN          VAUXHALL
# 2177202  2016984131216   56 - 65         NaN               NaN
# 2177203  2016984131316   16 - 20        13.0          VAUXHALL
# 2177204  2016984133416   46 - 55         5.0             MAZDA
#
#                          model     sex   VehicleManoeuvre
# 0               45 CLASSIC 16V    Male  Going ahead other
# 1                           C1    Male  Going ahead other
# ...

# %%
vehicle0.sex.unique()
# Out:
# array(['Male', 'Female', 'Not known', 'Data missing or out of range'],
#       dtype=object)

# %%
df_vehicle = vehicle0[vehicle0.sex != 'Data missing or out of range']

# %%
df_vehicle1 = df_vehicle[df_vehicle.sex != 'Not known']

# %%
df_vehicle1.model.unique()
# Out:
# array(['45 CLASSIC 16V', 'C1', 'MICRA CELEBRATION 16V', ...,
#        'HILUX VIGO G D4-D AUTO', 'SOLO M1030', 'DAILY 35 C14 MWB'],
#       dtype=object)

# %%
df_vehicle1.make.unique()
# Out:
# array(['ROVER', 'BMW', 'NISSAN', 'LONDON TAXIS INT', 'PIAGGIO',
#        'VOLKSWAGEN', 'MERCEDES', 'FORD', 'DENNIS', 'VAUXHALL', 'VOLVO',
#        'FIAT', 'RENAULT', 'AUDI', 'MAN', 'HONDA', 'CHRYSLER', 'ISUZU',
#        'LAND ROVER', 'YAMAHA', 'MINI', 'KAWASAKI', 'GILERA', 'SAAB',
#        'CITROEN', 'MASERATI', 'SUBARU', 'DUCATI', 'BEDFORD', 'PEUGEOT',
#        'APRILIA', 'LEYLAND', 'MITSUBISHI', 'ALFA ROMEO', 'SCANIA',
#        'FERRARI', 'TRIUMPH', 'LEYLAND AEC', 'ITALJET', 'DAEWOO', 'JAGUAR',
#        'HARLEY-DAVIDSON', 'SUZUKI', 'SKODA', 'IVECO-FORD', 'TOYOTA',
#        'AUSTIN', 'IVECO', 'LEXUS', 'METROCAB', 'DAF', 'MCC', 'JEEP', 'MG',
#        'MZ', 'TRANSBUS INT', 'VESPA (DOUGLAS)', 'SEAT', 'BUELL', 'DEMM',
#        'KTM', 'NEOPLAN', 'MAZDA', 'HYUNDAI', 'SEDDON/ATKINSON', 'HONGYI',
#        'TAIWAN GOLDEN BEE', 'PORSCHE', 'DAIMLER', 'DI BLASI',
#        'DAF TRUCKS', 'MOTO GUZZI', 'MCW', 'SYM', 'MORRIS',
# ...

# %%
df_vehicle1.vehicleAge.unique()
# Out:
# array([  3.,  nan,   4.,   1.,  10.,   2.,  11.,   6.,   9.,   5.,  13.,
#         15.,   7.,  12.,   8.,  16.,  14.,  28.,  41.,  17.,  37.,  21.,
#         27.,  23.,  20.,  24.,  18.,  25.,  38.,  40.,  39.,  26.,  42.,
#         36.,  19.,  22.,  30.,  34.,  32.,  29.,  31.,  33.,  45.,  35.,
#         49.,  43.,  48.,  71.,  47.,  52.,  46.,  44.,  53.,  51.,  50.,
#         76.,  85.,  58.,  78.,  64.,  80.,  61.,  68.,  59.,  54.,  63.,
#         55.,  57.,  65.,  60.,  56.,  66.,  72.,  70.,  75.,  69.,  95.,
#         83.,  79.,  73., 111.,  77.,  74., 104.,  90., 105.,  91.,  84.,
#         67.])

# %%
df_vehicle1.driverAge.unique()
# Out:
# array(['26 - 35', '66 - 75', '36 - 45', '46 - 55', '21 - 25',
#        'Data missing or out of range', '16 - 20', '56 - 65', 'Over 75',
#        '11 - 15', '6 - 10', '0 - 5'], dtype=object)

# %%
df_vehicle2 = df_vehicle1[df_vehicle1.driverAge != 'Data missing or out of range']

# %%
df_vehicle2.id.unique()
# Out:
# array(['200401BS00001', '200401BS00002', '200401BS00003', ...,
#        '2016984131216', '2016984131316', '2016984133416'], dtype=object)

# %%
df_vehicle2.VehicleManoeuvre.unique()
# Out:
# array(['Going ahead other', 'Turning right', 'U-turn',
#        'Slowing or stopping', 'Going ahead right-hand bend',
#        'Waiting to go - held up', 'Moving off', 'Parked',
#        'Going ahead left-hand bend',
#        'Overtaking moving vehicle - offside', 'Changing lane to right',
#        'Waiting to turn right', 'Turning left', 'Overtaking - nearside',
#        'Overtaking static vehicle - offside', 'Reversing',
#        'Changing lane to left', 'Waiting to turn left',
#        'Data missing or out of range'], dtype=object)

# %%
df_vehicle3 = df_vehicle2[df_vehicle2.VehicleManoeuvre != 'Data missing or out of range']

# %%
df_vehicle3
# Out:
#                     id driverAge  vehicleAge              make  \
# 0        200401BS00001   26 - 35         3.0             ROVER
# 1        200401BS00002   26 - 35         NaN               BMW
# 2        200401BS00003   26 - 35         4.0            NISSAN
# 3        200401BS00003   66 - 75         NaN  LONDON TAXIS INT
# 4        200401BS00004   26 - 35         1.0           PIAGGIO
# ...                ...       ...         ...               ...
# 2177200  2016984131116   21 - 25        14.0              MINI
# 2177201  2016984131116   56 - 65         NaN          VAUXHALL
# 2177202  2016984131216   56 - 65         NaN               NaN
# 2177203  2016984131316   16 - 20        13.0          VAUXHALL
# 2177204  2016984133416   46 - 55         5.0             MAZDA
#
#                          model     sex   VehicleManoeuvre
# 0               45 CLASSIC 16V    Male  Going ahead other
# 1                           C1    Male  Going ahead other
# ...

# %%
vehicle_data = df_vehicle3.dropna()
vehicle_data
# Out:
#                     id driverAge  vehicleAge        make  \
# 0        200401BS00001   26 - 35         3.0       ROVER
# 2        200401BS00003   26 - 35         4.0      NISSAN
# 4        200401BS00004   26 - 35         1.0     PIAGGIO
# 9        200401BS00013   26 - 35         4.0  VOLKSWAGEN
# 10       200401BS00013   21 - 25         3.0        FORD
# ...                ...       ...         ...         ...
# 2177196  2016984130816   36 - 45         1.0      NISSAN
# 2177198  2016984130916   46 - 55         8.0        SEAT
# 2177200  2016984131116   21 - 25        14.0        MINI
# 2177203  2016984131316   16 - 20        13.0    VAUXHALL
# 2177204  2016984133416   46 - 55         5.0       MAZDA
#
#                          model     sex             VehicleManoeuvre
# 0               45 CLASSIC 16V    Male            Going ahead other
# 2        MICRA CELEBRATION 16V    Male                Turning right
# 4                    VESPA ET4    Male            Going ahead other
# ...

# %% [markdown]
# ## Final vehicle_data file

# %%
vehicle_data.set_index("id")
# Out:
#               driverAge  vehicleAge        make                  model  \
# id
# 200401BS00001   26 - 35         3.0       ROVER         45 CLASSIC 16V
# 200401BS00003   26 - 35         4.0      NISSAN  MICRA CELEBRATION 16V
# 200401BS00004   26 - 35         1.0     PIAGGIO              VESPA ET4
# 200401BS00013   26 - 35         4.0  VOLKSWAGEN                GOLF V5
# 200401BS00013   21 - 25         3.0        FORD     TRANSIT 350 LWB TD
# ...                 ...         ...         ...                    ...
# 2016984130816   36 - 45         1.0      NISSAN  X-TRAIL N-TEC DCI 4X4
# 2016984130916   46 - 55         8.0        SEAT    IBIZA ECOMOTIVE TDI
# 2016984131116   21 - 25        14.0        MINI            MINI COOPER
# 2016984131316   16 - 20        13.0    VAUXHALL         VECTRA SXI 16V
# 2016984133416   46 - 55         5.0       MAZDA      CX-7 SPORT TECH D
#
#                   sex             VehicleManoeuvre
# id
# 200401BS00001    Male            Going ahead other
# ...

# %% [markdown]
# # Connecting to Postgresql (relational Database) and loading the cleaned data.

# %%
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect
import pandas as pd
import os

# %%
! pip3 install psycopg2.binary
# Out:
# ...
# WARNING: Error parsing requirements for ipython: [Errno 2] No such file or directory: '/Users/Farzana/opt/anaconda3/lib/python3.9/site-packages/ipython-8.2.0.dist-info/METADATA'

# %%
pip install config
# Out:
# ...
# WARNING: Error parsing requirements for ipython: [Errno 2] No such file or directory: '/Users/Farzana/opt/anaconda3/lib/python3.9/site-packages/ipython-8.2.0.dist-info/METADATA'
# Note: you may need to restart the kernel to use updated packages.

# %%
from config import password

# %%
protocol = "postgresql"
port = 5433
database_name = "Accident_db"
username = "postgres"

# %%
engine = create_engine(f'postgresql://{username}:{password}@localhost:5433/Accident_db')
connection = engine.connect()

# %%
inspector = inspect(engine)

# %%
inspector.get_table_names()
# Out:
# ['vehicle_data', 'accident_data']

# %%
accident_data.to_sql('accident_data', connection, if_exists= 'replace')
# Out:
# 974

# %%
vehicle_data.to_sql('vehicle_data', connection, if_exists= 'replace')
# Out:
# 856

# %% [markdown]
# # Loading cleaned data to non-relational database MongoDB

# %%
accident_data.head()
# Out:
#               id severity        day  SpeedLimit RoadConditions  \
# 0  200501BS00001  Serious    Tuesday          30    Wet or damp
# 1  200501BS00002   Slight  Wednesday          30            Dry
# 2  200501BS00003   Slight   Thursday          30            Dry
# 3  200501BS00004   Slight     Friday          30            Dry
# 4  200501BS00005   Slight     Monday          30    Wet or damp
#
#                  weather
# 0  Raining no high winds
# 1     Fine no high winds
# 2     Fine no high winds
# 3     Fine no high winds
# 4     Fine no high winds

# %%
# convert pandas dataframe to dictionary
accident_data_dict = accident_data.to_dict('records')
accident_data_dict[:5]
# Out:
# [{'id': '200501BS00001',
#   'severity': 'Serious',
#   'day': 'Tuesday',
#   'SpeedLimit': 30,
#   'RoadConditions': 'Wet or damp',
#   'weather': 'Raining no high winds'},
#  {'id': '200501BS00002',
#   'severity': 'Slight',
#   'day': 'Wednesday',
#   'SpeedLimit': 30,
#   'RoadConditions': 'Dry',
#   'weather': 'Fine no high winds'},
#  {'id': '200501BS00003',
#   'severity': 'Slight',
#   'day': 'Thursday',
#   'SpeedLimit': 30,
#   'RoadConditions': 'Dry',
#   'weather': 'Fine no high winds'},
#  {'id': '200501BS00004',
#   'severity': 'Slight',
#   'day': 'Friday',
#   'SpeedLimit': 30,
#   'RoadConditions': 'Dry',
#   'weather': 'Fine no high winds'},
#  {'id': '200501BS00005',
#   'severity': 'Slight',
#   'day': 'Monday',
#   'SpeedLimit': 30,
#   'RoadConditions': 'Wet or damp',
#   'weather': 'Fine no high winds'}]

# %%
vehicle_data.head()
# Out:
#                id driverAge  vehicleAge        make                  model  \
# 0   200401BS00001   26 - 35         3.0       ROVER         45 CLASSIC 16V
# 2   200401BS00003   26 - 35         4.0      NISSAN  MICRA CELEBRATION 16V
# 4   200401BS00004   26 - 35         1.0     PIAGGIO              VESPA ET4
# 9   200401BS00013   26 - 35         4.0  VOLKSWAGEN                GOLF V5
# 10  200401BS00013   21 - 25         3.0        FORD     TRANSIT 350 LWB TD
#
#        sex             VehicleManoeuvre
# 0     Male            Going ahead other
# 2     Male                Turning right
# 4     Male            Going ahead other
# 9   Female                Turning right
# 10    Male  Going ahead right-hand bend

# %%
# convert pandas dataframe to dictionary
vehicle_data_dict = vehicle_data.to_dict('records')
vehicle_data_dict[:5]
# Out:
# [{'id': '200401BS00001',
#   'driverAge': '26 - 35',
#   'vehicleAge': 3.0,
#   'make': 'ROVER',
#   'model': '45 CLASSIC 16V',
#   'sex': 'Male',
#   'VehicleManoeuvre': 'Going ahead other'},
#  {'id': '200401BS00003',
#   'driverAge': '26 - 35',
#   'vehicleAge': 4.0,
#   'make': 'NISSAN',
#   'model': 'MICRA CELEBRATION 16V',
#   'sex': 'Male',
#   'VehicleManoeuvre': 'Turning right'},
#  {'id': '200401BS00004',
#   'driverAge': '26 - 35',
#   'vehicleAge': 1.0,
#   'make': 'PIAGGIO',
#   'model': 'VESPA ET4',
#   'sex': 'Male',
#   'VehicleManoeuvre': 'Going ahead other'},
#  {'id': '200401BS00013',
#   'driverAge': '26 - 35',
#   'vehicleAge': 4.0,
#   'make': 'VOLKSWAGEN',
#   'model': 'GOLF V5',
#   'sex': 'Female',
#   'VehicleManoeuvre': 'Turning right'},
#  {'id': '200401BS00013',
#   'driverAge': '21 - 25',
#   'vehicleAge': 3.0,
#   'make': 'FORD',
#   'model': 'TRANSIT 350 LWB TD',
#   'sex': 'Male',
#   'VehicleManoeuvre': 'Going ahead right-hand bend'}]

# %%
import pymongo
import json

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# create a mongodb database
db = client["Accident_db"]
# create collections
accident_table = db["accident_data"]
vehicle_table = db["vehicle_data"]

# %%
accident_table.insert_many(accident_data_dict)

# %%
vehicle_table.insert_many(vehicle_data_dict)
